# %% [markdown]
# ## 3.8 Методы списков

# %% [markdown]
# ![image001.jpg](attachment:d5198bb0-7a55-4158-bd73-17ccb0c2611c.jpg)

# %%
a = [1, -54, 3, 23, 43, -45, 0]
a.append(100)
print(a)
# Out:
# [1, -54, 3, 23, 43, -45, 0, 100]

# %% [markdown]
# ### Так нет, это приведёт к потере данных, так как данный метод append ничего не возвращает, а меняет сам список.
# ### append() возвращает значение None

# %%
a = a.append(100) 
print(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a = a.append(100)
#       2 print(a)
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
a = [1, -54, 3, 23, 43, -45, 0]
a.append("hello")
print(a)
# Out:
# [1, -54, 3, 23, 43, -45, 0, 'hello']

# %%
a.append(True)
print(a)
# Out:
# [1, -54, 3, 23, 43, -45, 0, 'hello', True]

# %%
a.append([1, 2, 3])
print(a)
# Out:
# [1, -54, 3, 23, 43, -45, 0, 'hello', True, [1, 2, 3]]

# %% [markdown]
# ### Так работать не будет

# %%
a.append(1, 2) 
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a.append(1, 2)
#       2 print(a)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %% [markdown]
# ### Вставляем в третию позицию под индексом a[3]

# %%
a = [1, -54, 3, 23, 43, -45, 0]
a.insert(3, -1000) 
print(a)
# Out:
# [1, -54, 3, -1000, 23, 43, -45, 0]

# %%
a.append(True)
print(a)
# Out:
# [1, -54, 3, -1000, 23, 43, -45, 0, True]

# %%
a.remove(True) # удалится цифра 1 под индексом [0]
print(a)
# Out:
# [-54, 3, -1000, 23, 43, -45, 0, True]

# %%
a.remove(True)
print(a)
# Out:
# [-54, 3, -1000, 23, 43, -45, 0]

# %%
a.pop() # удаляет последний элемент
print(a)
# Out:
# [-54, 3, -1000, 23, 43, -45]

# %%
end = a.pop()
print(f"end = {end}")
print(f"a = {a}")
# Out:
# end = -45
# a = [-54, 3, -1000, 23, 43]

# %%
a.pop(3)
print(a)
# Out:
# [-54, 3, -1000, 43]

# %%
a.clear()
print(a)
# Out:
# []

# %%
a = [1, -54, 3, 23, 43, -45, 0]
c = a.copy()
print(f"a = {a}")
print(f"c = {c}")
# Out:
# a = [1, -54, 3, 23, 43, -45, 0]
# c = [1, -54, 3, 23, 43, -45, 0]

# %%
c = list(a)
print(c)
# Out:
# [1, -54, 3, 23, 43, -45, 0]

# %%
id(c)
# Out:
# 1925777329792

# %%
id(a)
# Out:
# 1925776528704

# %% [markdown]
# ### метод count позволяет найти число элементов с указанным значением:

# %%
print(c)
# Out:
# [1, -54, 3, 23, 43, -45, 0]

# %%
c.count(1)
# Out:
# 1

# %%
c.count(-45)
# Out:
# 1

# %%
c.insert(3, 23)
print(c)
# Out:
# [1, -54, 3, 23, 23, 43, -45, 0]

# %%
c.count(23)
# Out:
# 2

# %% [markdown]
# ### Если же нам нужен индекс определенного значения, то для этого используется метод index:

# %%
c.index(-45)
# Out:
# 6

# %%
c.index(1)
# Out:
# 0

# %%
print(c)
# Out:
# [1, -54, 3, 23, 23, 43, -45, 0]

# %%
c.index(23, 1) # ищем число 23 с первого элемента
# Out:
# 3

# %%
c.index(23, 1, 5) # Ищем число 23 с первого по пятый элемент
# Out:
# 3

# %%
23 in c[1:3]
# Out:
# False

# %%
23 in c[3:]
# Out:
# True

# %%
c.index(23, 3)
# Out:
# 3

# %%
print(c)
# Out:
# [1, -54, 3, 23, 23, 43, -45, 0]

# %%
c.reverse()
print(c)
# Out:
# [0, -45, 43, 23, 23, 3, -54, 1]

# %%
c.sort()
print(c)
# Out:
# [-54, -45, 0, 1, 3, 23, 23, 43]

# %%
c.sort(reverse=True)
print(c)
# Out:
# [43, 23, 23, 3, 1, 0, -45, -54]

# %%
lst = ["Москва", "Санкт-Петербург", "Тверь", "Казань"]
lst.sort()
print(lst)
# Out:
# ['Казань', 'Москва', 'Санкт-Петербург', 'Тверь']

# %% [markdown]
# ### Отличие метода sort() от ранее рассмотренной функции sorted() в том, что метод меняет сам список, а функция sorted() возвращает новый отсортированный список, не меняя начальный.

# %%
sorted(c)
# Out:
# [-54, -45, 0, 1, 3, 23, 23, 43]

# %%
print(c)
# Out:
# [43, 23, 23, 3, 1, 0, -45, -54]

# %%
a = [1, -54, 3, 23, 43, -45, 0]
print(a)
# Out:
# [1, -54, 3, 23, 43, -45, 0]

# %%
sorted(a)
# Out:
# [-54, -45, 0, 1, 3, 23, 43]

# %%
print(a)
# Out:
# [1, -54, 3, 23, 43, -45, 0]

# %%
a.sort()
print(a)
# Out:
# [-54, -45, 0, 1, 3, 23, 43]

# %% [markdown]
# |      Метод       |                          Описание                             |
# |------------------|---------------------------------------------------------------|
# |     append()     |    Добавляет элемент в конец списка                           |
# |     insert()     |  Вставляет элемент в указанное место списка                   |
# |     remove()     |  Удаляет элемент по значению                                  |
# |     pop()        |  Удаляет последний элемент, либо элемент с указанным индексом |
# |     clear()      |  Очищает список (удаляет все элементы)                        |
# |     copy()       |  Возвращает копию списка                                      |
# |     count()      |  Возвращает число элементов с указанным значением             |
# |     index()      |  Возвращает индекс первого найденного элемента                |
# |     reverse()    |  Меняет порядок следования элементов на обратный              |
# |     sort()       |  Сортирует элементы списка                                    |

# %% [markdown]
# ![lists.png](attachment:ef65ef8a-ad31-4ac0-96df-98433304e9fe.png)

# %%
lst = list(map(int, input().split()))
lst.append(lst[0] != lst[-1])
print(*lst)
# Out:
#  8 23 4 6
# 8 23 4 6 True

# %%
cities = ["Москва", "Казань", "Ярославль"]
cities.insert(1, "Ульяновск") # сначала куда, потом что.
print(*cities)
# Out:
# Москва Ульяновск Казань Ярославль

# %%
lst = list(input())
lst.remove('+')
lst.pop(0)
lst.insert(0, '8')
lst.remove('-')
lst.remove('-')
print("".join(lst))

# print(input().replace('+7', '8').replace('-', ''))
# Out:
#  +7(912)123-45-67
# 8(912)1234567

# %%
lst = input().split()
lst = "".join(lst[2] + " " + lst[0][0] + '.' + lst[1][0] + '.')
print(lst)
# Out:
#  Сергей Михайлович Балакирев
# Балакирев С.М.

# %%
lst = list(map(int, input().split()))
new = sorted(lst)[:3]
print(*new)
# Out:
#  8 11 -5 10 -1 0 7
# -5 -1 0

# %%
lst = list(map(int, input().split()))
bol = lst[-1] % 2 != 0 
# lst.append(lst.pop() % 2 != 0)
# lst[-1] = lst[-1] % 2 != 0
# lst.append(bool(lst.pop()%2))
lst.pop()
lst.append(bol)
print(*lst)
# Out:
#  8 11 0 3 5 6
# 8 11 0 3 5 False

# %%
lst = list(input().split())
print(lst.count('2'))
# Out:
#  2 3 5 2 4 2 2 5
# 4

# %%
lst = input().split()
lst.sort()
lst.pop(0)
print(*lst)
# Out:
#  Лена Обь Волга Дон Енисей
# Дон Енисей Лена Обь
