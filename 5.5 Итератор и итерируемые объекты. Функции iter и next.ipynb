# %% [markdown]
# ## 5.5 Итератор и итерируемые объекты. Функции iter и next

# %%
d = [5, 3, 7, 10, 32]
# iter(d)
it = iter(d)

# %% [markdown]
# ![image002.jpg](attachment:83fd5405-cabf-4977-b357-91d2451b7c4b.jpg)

# %%
next(it)
# Out:
# 5

# %%
next(it)
# Out:
# 3

# %%
next(it)
# Out:
# 7

# %%
next(it)
# Out:
# 10

# %%
next(it)
# Out:
# 32

# %%
next(it)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 next(it)
#
# StopIteration:

# %%
it = iter(d)
next(it)
# Out:
# 5

# %%
s = "python"
it_s = iter(s)

# %%
next(it_s)
# Out:
# 'p'

# %%
next(it_s)
# Out:
# 'y'

# %%
next(it_s)
# Out:
# 't'

# %%
next(it_s)
# Out:
# 'h'

# %%
next(it_s)
# Out:
# 'o'

# %%
next(it_s)
# Out:
# 'n'

# %%
r = range(5)
it = iter(r)
next(it)
# Out:
# 0

# %%
next(it)
# Out:
# 1

# %%
next(it)
# Out:
# 2

# %%
next(it)
# Out:
# 3

# %%
next(it)
# Out:
# 4

# %%
next(it)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 next(it)
#
# StopIteration:

# %%
for x in [5, 3, 7, 10, 32]:
    print(x)
# Out:
# 5
# 3
# 7
# 10
# 32

# %%
for x in "python":
    print(x)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for x in range(1, 6):
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
iter(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 iter(5)
#
# TypeError: 'int' object is not iterable

# %%
lst = input().split()
it = iter(lst)
print(next(it))
print(next(it))
# Out:
#  Москва Лондон Берлин Пекин
# Москва
# Лондон

# %%
s = input()
it = iter(s)
for x in it:
    if x == ' ':
        break
    print(x, end='')
# Out:
#  Возможно-это будет полезно
# Возможно-это

# %%
num = input()
it = iter(num)
for i in it:
    print(i, end=' ')
# Out:
#  4387
# 4 3 8 7
