# %% [markdown]
# ## 3.6 Списки и операции над ними

# %%
["Москва", "Тверь", "Вологда"]
# Out:
# ['Москва', 'Тверь', 'Вологда']

# %%
marks = [2, 3, 4, 3, 5, 2]
marks
# Out:
# [2, 3, 4, 3, 5, 2]

# %%
marks[0]
# Out:
# 2

# %%
marks[2]
# Out:
# 4

# %%
avg = (marks[0] + marks[1] + marks[2] + marks[3] + marks[4] + marks[5] / 6)
print(avg)
# Out:
# 17.333333333333332

# %%
marks[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 marks[10]
#
# IndexError: list index out of range

# %%
marks[-1]
# Out:
# 2

# %% [markdown]
# ### Список – изменяемый тип данных

# %%
print(marks)
# Out:
# [2, 3, 4, 3, 5, 2]

# %%
marks[0] = 3
print(marks)
# Out:
# [3, 3, 4, 3, 5, 2]

# %%
marks[1] = "удовл."
marks
# Out:
# [3, 'удовл.', 4, 3, 5, 2]

# %%
lst = ["Москва", 1320, 5.8, True, "Тверь", False]
lst
# Out:
# ['Москва', 1320, 5.8, True, 'Тверь', False]

# %%
lst2 = [1, 2.5, [-1, -2, -3], 4]
lst2
# Out:
# [1, 2.5, [-1, -2, -3], 4]

# %%
a = []
a
# Out:
# []

# %%
b = list()
print(b)
# Out:
# []

# %%
a = list([True, False])
print(a)
# Out:
# [True, False]

# %%
list("Python")
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %% [markdown]
# ## Функции работы со списками

# %% [markdown]
# * len() - определение числа элементов в списке (длина списка);
# * max() - для нахождения максимального значения;
# * min() - для находждения минимального значения;
# * sum() - для вычисления суммы;
# * sorted() - для сортировки коллекции.

# %%
print(marks)
# Out:
# [3, 'удовл.', 4, 3, 5, 2]

# %%
marks[1] = 3
print(marks)
# Out:
# [3, 3, 4, 3, 5, 2]

# %%
marks[0] = 2
print(marks)
# Out:
# [2, 3, 4, 3, 5, 2]

# %%
len(marks)
# Out:
# 6

# %%
len([])
# Out:
# 0

# %%
t = [23.5, 25.6, 27.3, 26.0, 30.4, 29.5]
max(t)
# Out:
# 30.4

# %%
min(t)
# Out:
# 23.5

# %%
sum(t)
# Out:
# 162.3

# %%
sum(t)/len(t) # средняя температура
# Out:
# 27.05

# %%
t_sort = sorted(t)
t_sort
# Out:
# [23.5, 25.6, 26.0, 27.3, 29.5, 30.4]

# %%
sorted(t, reverse=True)
# Out:
# [30.4, 29.5, 27.3, 26.0, 25.6, 23.5]

# %%
s = list("python")

# %%
max(s)
# Out:
# 'y'

# %%
min(s)
# Out:
# 'h'

# %%
sorted(s)
# Out:
# ['h', 'n', 'o', 'p', 't', 'y']

# %%
sum(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sum(s)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## Операторы списков

# %% [markdown]
# * ' + '  соединение двух списков в один;
# * ' * '  дублирование списка;
# * in - проверка вхождение элемента в список;
# * del - удаление элемента списка.

# %%
[1, 2, 3] + [4, 5]
# Out:
# [1, 2, 3, 4, 5]

# %%
[1, 2, 3] + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 [1, 2, 3] + 4
#
# TypeError: can only concatenate list (not "int") to list

# %%
[1, 2, 3] + [4]
# Out:
# [1, 2, 3, 4]

# %%
[1, 2, 3] + [True]
# Out:
# [1, 2, 3, True]

# %%
["I", "l you", "Python"] * 3
# Out:
# ['I', 'l you', 'Python', 'I', 'l you', 'Python', 'I', 'l you', 'Python']

# %%
["I"] + ["love"] * 3 + ["Python"]
# Out:
# ['I', 'love', 'love', 'love', 'Python']

# %%
lst = ["Москва", 1320, 5.8, True, "Тверь", False]
1320 in lst
# Out:
# True

# %%
120 in lst
# Out:
# False

# %%
lst = ["Москва", 1320, 5.8, True, "Тверь", False, [1, 2]]
[1, 2] in lst
# Out:
# True

# %%
"Москва" in lst
# Out:
# True

# %%
print(lst)
# Out:
# ['Москва', 1320, 5.8, True, 'Тверь', False, [1, 2]]

# %%
del lst[2]
lst
# Out:
# ['Москва', 1320, True, 'Тверь', False, [1, 2]]

# %%
lst = list(map(int, input().split()))
print(lst)
# Out:
#  8 11 3
# [8, 11, 3]

# %%
cities = input().split()
print("Москва" in cities)
# Out:
#  Тверь Уфа Москва Казань
# True

# %%
cities = input().split()
print(cities[-1])
# Out:
#  Тверь Уфа Москва Казань
# Казань

# %%
marks = list(map(int, input().split()))
avg = round(sum(marks) / len(marks), 1)
print(avg)
# print(f"{sum(marks)/len(marks):.1f}")
# Out:
#  3 3 2 4 4 5 4 3 2
# 3.3

# %%
title = input()
author = input()
number_of_pages = int(input())
price = float(input())
book = list([title, author, number_of_pages, price])
del book[2]
print(book)
book[1] = "Пушкин"
book[2] = book[2] * 2
print(book)

# print([input(), input() * 0 + input() * 0 + 'Пушкин', float(input()) * 2])

# book = [input(), input(),int(input()), float(input())]
# del book[2]
# book[1] = 'Пушкин'
# book[2] *= 2
# Out:
#  Мастер и Маргарита
#  Булгаков
#  233
#  435.45
# ['Мастер и Маргарита', 'Булгаков', 435.45]
# ['Мастер и Маргарита', 'Пушкин', 870.9]

# %%
count = list(map(int, input().split()))
print(max(count), min(count), sum(count))
# Out:
#  1 2 3 4
# 4 1 10

# %%
lst = sorted(list(map(int, input().split())), reverse=True)
print(*lst)
# Out:
#  52 65 64 54 68 59 42 63
# 68 65 64 63 59 54 52 42

# %%
n = input().split()
cities = ["Москва", "Тверь", "Вологда"]
lst = cities + n
print(*lst)
# print(' '.join(["Москва", "Тверь", "Вологда"]), input())
# print(*["Москва", "Тверь", "Вологда"] + input().split())
# Out:
#  Уфа Казань Севастополь
# Москва Тверь Вологда Уфа Казань Севастополь

# %%
lst = input().split()
cities = ["Москва", "Тверь", "Вологда"]
lst = lst + cities
print(*lst)

# print(input(), ' '.join(["Москва", "Тверь", "Вологда"]))
# lst.extend(cities) # добавляет все элементы из списка cities в конец списка lst
# Out:
#  Уфа Казань Севастополь
# Уфа Казань Севастополь Москва Тверь Вологда
