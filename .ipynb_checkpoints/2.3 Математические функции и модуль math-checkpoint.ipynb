# %% [markdown]
# ## 2.3 Математические функции и модуль math

# %%
abs(-5)
# Out:
# 5

# %%
a = abs(-5.6)
a
# Out:
# 5.6

# %%
abs(1.5)
# Out:
# 1.5

# %%
max(1,2,3,0,-5,10)
# Out:
# 10

# %%
min(1,2,3, 0, -5, 10)
# Out:
# -5

# %%
max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 max()
#
# TypeError: max expected at least 1 argument, got 0

# %%
pow(6,2)
# Out:
# 36

# %%
6 ** 2
# Out:
# 36

# %%
pow(27, 0.5) # квадратный корень из 27
# Out:
# 5.196152422706632

# %%
pow(27, 1/3) # кубический корень из 27
# Out:
# 3.0

# %%
round(0.5)
# Out:
# 0

# %%
round(0.5000000001)
# Out:
# 1

# %%
round(1.5)
# Out:
# 2

# %%
round(2.5)
# Out:
# 2

# %%
round(3.5)
# Out:
# 4

# %%
round(4.5)
# Out:
# 4

# %%
round(7.8756, 2)
# Out:
# 7.88

# %%
round(7.8756, -1)
# Out:
# 10.0

# %%
round(78756, -2)
# Out:
# 78800

# %%
round(78756, -3)
# Out:
# 79000

# %%
max(1, 2, abs(-3), -10)
# Out:
# 3

# %%
max(1, 2, abs(min(10, 5, -3)), -10)
# Out:
# 3

# %%
import math

# %%
math.ceil(5.2)
# Out:
# 6

# %%
math.ceil(-5.2)
# Out:
# -5

# %%
math.floor(5.99)
# Out:
# 5

# %%
math.floor(-3.3)
# Out:
# -4

# %%
math.factorial(6)
# Out:
# 720

# %%
math.trunc(5.8)
# Out:
# 5

# %%
int(5.8)
# Out:
# 5

# %%
math.log2(4)
# Out:
# 2.0

# %%
math.log10(100)
# Out:
# 2.0

# %%
math.log(2.7)
# Out:
# 0.9932517730102834

# %%
math.log(27, 3)
# Out:
# 3.0

# %%
math.sqrt(49)
# Out:
# 7.0

# %%
math.sin(3.14/2)
# Out:
# 0.9999996829318346

# %%
math.cos(0)
# Out:
# 1.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.exp(2) # Экспоненциальный рост — когда скорость роста пропорциональна текущему значению
# Out:
# 7.38905609893065

# %%
d = int(input())
res = abs(d)
res
# Out:
#  -5
# 5

# %%
d1, d2, d3, d4, d5 = map(int, input().split())
res = min(d1, d2, d3, d4, d5)
res
# Out:
#  3 5 88 1 4
# 1

# %%
d1, d2, d3, d4, d5 = map(int, input().split())
res = max(d1, d2, d3, d4, d5)
res
# Out:
#  3 2 1 77 4
# 77

# %%
import math
a, b = map(int, input().split())
H = math.sqrt(a**2+b**2)
length = round(H,2)
length
# Out:
#  4 8
# 8.94

# %%
import math
n, k = map(int, input().split())
Cnk = math.factorial(n)/(math.factorial(k)*(math.factorial(n-k)))
Cnk
# Out:
#  4 3
# 4.0

# %%
import math
n, m = map(int, input().split())
total_bus = math.ceil((n + m) / 20)
total_bus
# Out:
#  11 10
# 2

# %%
x = int(input())
res = int(500 // (x * 0.9))
res
# Out:
#  120
# 4
