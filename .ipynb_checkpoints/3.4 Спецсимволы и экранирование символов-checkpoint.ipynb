# %% [markdown]
# ## 3.4 Спецсимволы и экранирование символов

# %%
text = """Hello
Python"""
print(text)
# Out:
# Hello
# Python

# %%
text
# Out:
# 'Hello\nPython'

# %%
len(text)
# Out:
# 12

# %%
t = "panda needs\npython"
print(t)
# Out:
# panda needs
# python

# %% [markdown]
# |  Обозначение  | Описание                                            |
# |---------------|-----------------------------------------------------|
# |     \n        |  Перевод строки                                     |
# |     \\        |  Символ обратного слеша                             |
# |     \'        |  Символ апостофа                                    |
# |     \"        |  Символ двойной кавычки                             |
# |     \a        |  Звуковой сигнал                                    |
# |     \b        |  Эмуляция клавиши BackSpace                         |
# |     \f        |  Перевод формата                                    |
# |     \r        |  Возврат каретки                                    |
# |     \t        |  Горизонтальная табуляция (размером в 4 пробела)    |
# |     \v        |  Вертикальная табуляция                             |
# |     \0        |  Символ Null (не признак конца строки)              |
# |     \xhh      |  Символ с шестнадцатеричным кодом hh                |
# |     \000      |  Символ с восьмеричным кодом 000                    |
# |     \N{id}    |  Идентификатор из кодовой таблицы Unicode           |
# |     \uhhhh    |  16-битный символ Unicode в шестнадцатиричной форме |
# |     \Uhhhhhhhh|  32-битный символ Unicode в шестнадцатиричной форме |
# |     \другое   |  Не является экранированной последовательностью     |

# %%
t = "\tpanda needs\npython"
print(t)
# Out:
# 	panda needs
# python

# %%
t = "\panda needs\npython"
print(t)
# Out:
# \panda needs
# python
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Pro\AppData\Local\Temp\ipykernel_8068\3180549449.py:1: SyntaxWarning: invalid escape sequence '\p'
#   t = "\panda needs\npython"

# %%
t = "panda \needs\ python"
print(t)
# Out:
# panda
# eeds\ python
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\Pro\AppData\Local\Temp\ipykernel_8068\3007294799.py:1: SyntaxWarning: invalid escape sequence '\ '
#   t = "panda \needs\ python"

# %%
t = "panda \\needs\\ python"
print(t)
# Out:
# panda \needs\ python

# %%
path = "D:\\Python\\Projects\\stepik\\tex1.py"
print(path)
# Out:
# D:\Python\Projects\stepik\tex1.py

# %%
path = "D:\Python\Projects\stepik\tex1.py"
print(path)
# Out:
# D:\Python\Projects\stepik	ex1.py
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Pro\AppData\Local\Temp\ipykernel_8068\2786285210.py:1: SyntaxWarning: invalid escape sequence '\P'
#   path = "D:\Python\Projects\stepik\tex1.py"

# %%
s = "Марка вина \"Ягодка\""
print(s)
# Out:
# Марка вина "Ягодка"

# %%
s = 'Марка вина "Ягодка"'
print(s)
# Out:
# Марка вина "Ягодка"

# %%
s = 'Марка вина \'Ягодка\''
print(s)
# Out:
# Марка вина 'Ягодка'

# %%
path = "D:\\Python\\Projects\\stepik\\tex1.py"
print(path)
# Out:
# D:\Python\Projects\stepik\tex1.py

# %% [markdown]
# #### r - строка чтобы не использовать обратный слеш для экранирования

# %%
path = r"D:\\Python\\Projects\\stepik\\tex1.py"
print(path)
# Out:
# D:\\Python\\Projects\\stepik\\tex1.py

# %%
print("Тема занятия \"спецсимволы\"")
# Out:
# Тема занятия "спецсимволы"

# %%
a, b = input().split()
print(a + "\\" + b)
# Out:
#  Hello Balakirev!
# Hello\Balakirev!

# %%
str = input()
print(str.replace(" ", "'", 1).replace(" ", "\""))
# Out:
#  My best friend is Python!
# My'best"friend"is"Python!

# %%
print(r"C:\WINDOWS\System32\drivers\etc\hosts")
# Out:
# C:\WINDOWS\System32\drivers\etc\hosts

# %%
str = input()
print(f"\"{str}\"")
# print(f'"{input()}"')
# print('"' + input() + '"')
# Out:
#  language
# "language"
