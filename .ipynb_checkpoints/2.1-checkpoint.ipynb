# %% [markdown]
# ## 2.1 Переменные, оператор присваивания, функции type и id

# %%
a = 7
print(a)
# Out:
# 7

# %%
var_a = "Pandas"
var_a
# Out:
# 'Pandas'

# %%
a = 6.8
b = a
print(b)
# Out:
# 6.8

# %%
b = "Hello"
b
# Out:
# 'Hello'

# %%
b = 0
b
# Out:
# 0

# %%
b = -8.4
b
# Out:
# -8.4

# %%
a = b = c = d = 0
print(a)
print(b)
print(c)
print(d)
# Out:
# 0
# 0
# 0
# 0

# %%
a, b = 1, 2
print(a)
print(b)
a, b = b, a
print(a)
print(b)
# Out:
# 1
# 2
# 2
# 1

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
x = 5.8
s = "Hello"
print(type(x), type(s))
# Out:
# <class 'float'> <class 'str'>

# %%
msg = "Message"
count = 0
arg = 0
Arg = 0

# %%
#help() #keywords

# %%
d25 = 3
print(d25)
# Out:
# 3
