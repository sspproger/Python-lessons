# %% [markdown]
# ## 2.7 Булевы подвиги

# %%
x = int(input())
print((x % 7 == 0) * 100)
# Out:
#  20
# 0

# %%
a, b, x = map(float,input().split())
# res_in = x >= a and x < b
res_in = a <= x < b
print(res_in)
res_not_in = x < a or x > b
print(res_not_in)
# Out:
#  1 5 3
# True
# False

# %%
a, b, c, d, x = map(float, input().split())
res_1 = a < x < b or c <= x <= d
res_2 = (x < a or x > b) and c <= x <= d
res_3 = (x < a or x > b) and (x < c or x > d)

# %%
x0, y0, x1, y1, x, y = map(int, input().split())
is_into_rect = x0 < x < x1 and y0 < y < y1
is_not_into_rect = (x < x0 or x > x1) or (y < y0 or y > y1)

# %%
rect_width, rect_height, w, h = map(int, input().split())
total = ((rect_width + w - 1) // w) * ((rect_height + h - 1) // h) - (rect_width // w) * (rect_height // h)
total
# Out:
#  640 480 64 48
# 0
