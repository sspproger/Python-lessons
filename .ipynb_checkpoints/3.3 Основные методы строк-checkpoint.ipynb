# %% [markdown]
# ## 3.3 Основные методы строк

# %%
s = "python"
s
# Out:
# 'python'

# %%
type(s)
# Out:
# str

# %%
s = s.upper() # верхний регистр
print(s)
# Out:
# PYTHON

# %%
s = s.lower() # нижний регистр
print(s)
# Out:
# python

# %% [markdown]
# ### String.count(sub[, start[, end]])
# * start - индекс, с которого начитается поиск;
# * end - индекс, которым заканчивается поиск.

# %%
msg = "abracadabra"
msg.count("ra")
# Out:
# 2

# %%
msg.count("ra", 4)
# Out:
# 1

# %%
msg.count("ra", 4, 10)
# Out:
# 0

# %%
msg.count("ra", 4, 11)
# Out:
# 1

# %% [markdown]
# ## String.find(sub[, start[, end]])

# %%
msg.find("br")
# Out:
# 1

# %%
msg.find("br", 2)
# Out:
# 8

# %%
msg.find("brr")
# Out:
# -1

# %% [markdown]
# ## String.rfind(sub[, start[, end]])

# %%
msg.rfind("br") # первое вхождение справа
# Out:
# 8

# %% [markdown]
# ## String.index(sub[, start[, end]])

# %%
msg.index("brr")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 msg.index("brr")
#
# ValueError: substring not found

# %% [markdown]
# ## String.replace(old, new, count=-1)
# ### Выполняет замену подстрок old на строку new и возвращает измененную строку.

# %%
msg = "abracadabra"
msg.replace("a", "o")
# Out:
# 'obrocodobro'

# %%
msg.replace("ab", "AB")
# Out:
# 'ABracadABra'

# %%
msg.replace("ab", "")
# Out:
# 'racadra'

# %%
msg.replace("a", 'o', 2)
# Out:
# 'obrocadabra'

# %% [markdown]
# ## String.isalpha()
# ### возвращает True, если строка целиком состоит из букв и False в противном случае

# %%
msg.isalpha()
# Out:
# True

# %%
"hello world".isalpha()
# Out:
# False

# %% [markdown]
# ## String.isdigit()
# ### возвращает True, если строка целиком состоит из цифр и False в противном случае

# %%
"5.6".isdigit()
# Out:
# False

# %%
"56".isdigit()
# Out:
# True

# %% [markdown]
# ## String.rjust(width[, fillchar = ‘ ‘])
# ### возвращает новую строку с заданным числом символов width и при необходимости слева добавляет символы fillchar

# %%
d = "abc"
d.rjust(5) # пять символов в строке
# Out:
# '  abc'

# %%
d = "12"
d.rjust(3, '0')
# Out:
# '012'

# %%
d = "12"
d.rjust(5, '0')
# Out:
# '00012'

# %%
d.rjust(3, "00")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 d.rjust(3, "00")
#
# TypeError: The fill character must be exactly one character long

# %%
d.rjust(1)
# Out:
# '12'

# %% [markdown]
# ## String.ljust(width[, fillchar = ‘ ‘])
# ### возвращает новую строку с заданным числом символов width, но добавляет символы fillchar справа

# %%
d.ljust(10, "*")
# Out:
# '12********'

# %% [markdown]
# ## String.split(sep=None, maxsplit=-1)
# ### возвращает коллекцию строк, на которые разбивается исходная строка String. Разбивка осуществляется по указанному сепаратору sep.

# %%
"Иванов Иван Иванович".split(" ")
# Out:
# ['Иванов', 'Иван', 'Иванович']

# %%
"Иванов Иван Иванович".split()
# Out:
# ['Иванов', 'Иван', 'Иванович']

# %%
digs = "1, 2,3, 4,5,6"
digs.replace(" ", "").split(",")
# Out:
# ['1', '2', '3', '4', '5', '6']

# %% [markdown]
# ## String.join(список)
# ### возвращает строку из объединенных элементов списка, между которыми будет разделитель String

# %%
d = digs.replace(" ", "").split(",")
", ".join(d)
# Out:
# '1, 2, 3, 4, 5, 6'

# %%
fio = "Иванов Иван Иванович"
fio2 = ",".join(fio.split())
print(fio2)
# Out:
# Иванов,Иван,Иванович

# %% [markdown]
# ## String.strip()
# ### удаляет пробелы и переносы строк в начале и конце строки

# %%
"    hello world         \n".strip()
# Out:
# 'hello world'

# %% [markdown]
# ## String.rstrip() и String.lstrip()
# ### удаляют пробелы и переносы строк только справа или только слева

# %%
"    hello world".lstrip()
# Out:
# 'hello world'

# %%
"hello world         \n".rstrip()
# Out:
# 'hello world'

# %% [markdown]
# |    Название                           |                   Описание                                       |
# |---------------------------------------|------------------------------------------------------------------|
# | String.upper()                        | Возвращает строку с заглавными буквами                           |
# | String.lower()                        | Возвращает строку с малыми буквами                               |
# | String.count(sub[.start[,end]])       | Определяет число вхождений подстроки в строке                    |
# | String.find(sub[, start[,end]])       | Возвращает индекс первого найденного вхождения                   |
# | String.rfind(sub[, start[, end]])     | Возвращает индекс первого найденного вхождения при поиске справа |
# | String.index(sub[, start[, end]])     | Возвращает индекс первого найденного вхождения                   |
# | String.replace(old, new, count=-1)    | Заменяет подстроку old на new                                    |
# | String.isalpha()                      | Определяет: состоит ли строка целиком из буквенных символов      |
# | String.isdigit()                      | Определяет: состоит ли строка целиком из цифр                    |
# | String.rjust(width[, fillchar = ‘ ‘]) | Расширяет строку, добавляя символы слева                         |
# | String.ljust(width[, fillchar = ‘ ‘]) | Расширяет строку, добавляя символы справа                        |
# | String.split(sep=None, maxsplit=-1)   | Разбивает строку на подстроки                                    |
# | String.join(список)                   | Объединяет коллекцию в строку                                    |
# | String.strip()                        | Удаляет пробелы и переносы строк справа и слева                  |
# | String.rstrip()                       | Удаляет пробелы и переносы строк справа                          |
# | String.lstrip()                       | Удаляет пробелы и переносы строк слева                           |

# %%
str = input().lower()
str1 = str[0].upper() + str[1:]
print(str1)
# Out:
#  HELLO
# Hello

# %%
# С заглавной каждое слово в предложении
print(input().title())
# Out:
#  HELLO
# Hello

# %%
# С заглавной только первое слово в предложении
print(input().capitalize())
# Out:
#  HELLO
# Hello

# %%
num = input().count("-")
print(num)
# Out:
#  osnovnye-metody-strok
# 2

# %%
index = input().find("ra")
print(index)
# Out:
#  abrakadabra
# 2

# %%
str = input().replace("---", "-").replace("--", "-")
print(str)
# Out:
#  dobavlyaem---slagi--slug-k--url---adresam
# dobavlyaem-slagi-slug-k-url-adresam

# %%
a, b, c = input().split()
print(a.rjust(3, '0'))
print(b.rjust(3, '0'))
print(c.rjust(3, '0'))
# Out:
#  8 11 123
# 008
# 011
# 123

# %%
str = input().split()
print(len(str))
# print(len(input().split()))
# Out:
#  I love Python
# 3

# %%
str = input().replace(" ", ";")
print(str)
# Out:
#  Москва Тверь Казань
# Москва;Тверь;Казань
