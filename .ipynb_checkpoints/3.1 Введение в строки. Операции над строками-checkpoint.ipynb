# %% [markdown]
# ## 3.1 Введение в строки. Операции над строками

# %%
s1 = "Панда"
s1
# Out:
# 'Панда'

# %%
s2 = 'Panda'
s2
# Out:
# 'Panda'

# %%
s2 = Panda
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 s2 = Panda
#
# NameError: name 'Panda' is not defined

# %%
text = '''Hello!
My name is Anton Pershin.
I am learning Python.'''
text
# Out:
# 'Hello!\nMy name is Anton Pershin.\nI am learning Python.'

# %%
print(text)
# Out:
# Hello!
# My name is Anton Pershin.
# I am learning Python.

# %%
a = ""
a
# Out:
# ''

# %%
a = " "
a
# Out:
# ' '

# %% [markdown]
# ### Базовые операции над строками

# %%
s1 = "Я люблю"
s2 = "язык Python"
s3 = s1 + s2
print(s3)
# Out:
# Я люблюязык Python

# %%
s3 = s1 + " " + s2
s3
# Out:
# 'Я люблю язык Python'

# %%
s3 = s1 + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 s3 = s1 + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
s3 = s1 + " " + str(5)
s3
# Out:
# 'Я люблю 5'

# %%
str(True)
# Out:
# 'True'

# %%
"xa " * 5
# Out:
# 'xa xa xa xa xa '

# %%
"xa " * 5.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 "xa " * 5.5
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
a = "hello"
len(a)
# Out:
# 5

# %%
len("")
# Out:
# 0

# %%
len("Python")
# Out:
# 6

# %%
'ab' in "abracadabra"
# Out:
# True

# %%
'abc' in "abracadabra"
# Out:
# False

# %%
a == "hello"
# Out:
# True

# %%
a == "Hello"
# Out:
# False

# %%
a != "hello"
# Out:
# False

# %%
a != "Hello"
# Out:
# True

# %%
a == " hello"
# Out:
# False

# %%
'кот' > 'кит'
# Out:
# True

# %%
'кот' > 'кот'
# Out:
# False

# %%
ord('K')
# Out:
# 75

# %%
ord('k')
# Out:
# 107

# %% [markdown]
# * (конкатенация) - соединение строк;
# * (дублирование) - размножение строкового фрагмента;
# * str() - функция для преобразования аргументов в строковое представление;
# * len() - вычисление дляны строки;
# * in - оператор для проверки вхождения подстроки в строку (возвращвет True or False);
# * операторы сравнения: == != > < <= >=
# * ord() - определение кода символа.

# %%
s1 = input()
s2 = input()
s1 + " " +s2
# Out:
#  hello python
#  i love you
# 'hello python i love you'

# %%
fio = "Сергей\nБалакирев"
print(fio)
# Out:
# Сергей
# Балакирев

# %%
fio = "Сергей\nБалакирев"
fio
# Out:
# 'Сергей\nБалакирев'

# %%
print((1+2)*('7' + '8'))
# Out:
# 787878

# %%
s1, s2 = input().split()
print((s1 + " ") * 2 + (s2 + " ") * 3, end="")
# Out:
#  hello python
# hello hello python python python

# %%
a, b = input().split()
print("Переменна a = " + a + ", переменная b = " + b)
# Out:
#  2 -5
# Переменна a = 2, переменная b = -5

# %%
str = input()
print(f"Cтрока: {str}. Длина: {len(str)}")
# Out:
#  hello Balakirev
# Cтрока: hello Balakirev. Длина: 15

# %%
s1, s2 = input().split()
print(s1 in s2, s1 == s2, s1 > s2, s1 < s2)
# Out:
#  hello python
# False False False True

# %%
a, b = input().split()
print(f"Коды: {a} = {ord(a)}, {b} = {ord(b)}")
# Out:
#  a z
# Коды: a = 97, z = 122
